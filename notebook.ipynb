# 24/06/20, 6:43 pm - Sam😎: <Media omitted>
# 24/06/20, 10:21 pm - Akash Boyz: c mathroll
# 24/06/20, 10:35 pm - Sam😎: <Media omitted>
# 24/06/20, 10:38 pm - Akash Boyz: ahm n
# 24/06/20, 10:38 pm - Akash Boyz: nokate
# 25/06/20, 10:41 am - Akash Boyz: <Media omitted>
# 25/06/20, 10:49 am - Sam😎: <Media omitted>
# 25/06/20, 10:49 am - Akash Boyz: daa pinney... aa mouse gesture onnum wrk aavanilla
# 25/06/20, 10:49 am - Sam😎: <Media omitted>
# 25/06/20, 10:49 am - Akash Boyz: ahm
# 25/06/20, 10:50 am - Akash Boyz: <Media omitted>
# 25/06/20, 10:51 am - Sam😎: <Media omitted>
# 25/06/20, 10:52 am - Akash Boyz: nokate
# 25/06/20, 10:52 am - Akash Boyz: ithaana
# 25/06/20, 10:53 am - Akash Boyz: <Media omitted>
# 25/06/20, 11:14 am - Sam😎: Atheda..
# 25/06/20, 12:12 pm - Akash Boyz: ahm
# 25/06/20, 12:12 pm - Akash Boyz: volume label aana d nn kodukane
# 25/06/20, 12:24 pm - Sam😎: <Media omitted>
# 25/06/20, 12:28 pm - Akash Boyz: ok
# 25/06/20, 12:29 pm - Akash Boyz: ithipo ethra size aan
# 25/06/20, 12:33 pm - Sam😎: <Media omitted>
# 25/06/20, 12:37 pm - Akash Boyz: ipo  lapil storage engana partition cheythekane
# 25/06/20, 1:14 pm - Akash Boyz: eda ennitum aah disk this pc l kaananilla
# 25/06/20, 1:24 pm - Sam😎: <Media omitted>
# 25/06/20, 1:36 pm - Akash Boyz: aahda
# 25/06/20, 1:36 pm - Akash Boyz: set aay
# 25/06/20, 1:36 pm - Akash Boyz: pinne eda ee brightness control cheyyan pattanilla
# 25/06/20, 2:02 pm - Sam😎: Nee aa fn keg njekky pidichonde function key njekke
# 25/06/20, 2:03 pm - Akash Boyz: nerthe pattanidarnilla
# 25/06/20, 2:03 pm - Akash Boyz: ippa sheri aay
# 25/06/20, 2:03 pm - Sam😎: ✌🏻
# 25/06/20, 2:04 pm - Akash Boyz: <Media omitted>
# 25/06/20, 2:06 pm - Sam😎: <Media omitted>
# 25/06/20, 2:07 pm - Akash Boyz: eth version❓
# 25/06/20, 2:52 pm - Sam😎: <Media omitted>
# 25/06/20, 5:42 pm - Akash Boyz: oki
# 25/06/20, 8:39 pm - Akash Boyz: <Media omitted>
# 25/06/20, 8:39 pm - Akash Boyz: ithentha ingane
# 25/06/20, 9:09 pm - Sam😎: <Media omitted>
# 25/06/20, 9:13 pm - Akash Boyz: aanalle
# 25/06/20, 9:13 pm - Akash Boyz: 😂
# 25/06/20, 9:13 pm - Akash Boyz: maatan valla vazhi inda
# 25/06/20, 9:13 pm - Sam😎: <Media omitted>
# 25/06/20, 9:15 pm - Akash Boyz: desktop il maathrm ullu
# 25/06/20, 9:15 pm - Sam😎: <Media omitted>
# 25/06/20, 9:17 pm - Akash Boyz: ahm noka
# 25/06/20, 9:17 pm - Akash Boyz: feature aanen thonnanill
# 18/09/20, 2:57 pm - Sam😎: <Media omitted>
# 18/09/20, 3:00 pm - Akash Boyz: clsooooo
# 18/09/20, 3:00 pm - Akash Boyz: eth clssss
# 18/09/20, 3:00 pm - Akash Boyz: online alle❓
# 18/09/20, 3:02 pm - Sam😎: <Media omitted>
# 18/09/20, 3:03 pm - Akash Boyz: adipoli
# 18/09/20, 3:03 pm - Akash Boyz: nee onn nok
# 18/09/20, 3:03 pm - Akash Boyz: patto nn
# 18/09/20, 3:04 pm - Sam😎: <Media omitted>
# 18/09/20, 3:04 pm - Akash Boyz: nta chettan nikkana oru kada aan
# 18/09/20, 3:04 pm - Akash Boyz: allel vere nokan parayam
# 18/09/20, 3:04 pm - Sam😎: Sthalam evadaada
# 18/09/20, 3:05 pm - Akash Boyz: menaka avde evdo aano
# 18/09/20, 3:08 pm - Akash Boyz: eda ith cheyyan rate ethrayavum❓
# 18/09/20, 3:09 pm - Akash Boyz: njney ninte num kodukatte
# 18/09/20, 7:18 pm - Akash Boyz: daaa
# 19/09/20, 7:05 am - Sam😎: <Media omitted>
# 19/09/20, 7:05 am - Sam😎: <Media omitted>
# 19/09/20, 8:19 am - Akash Boyz: <Media omitted>
# 19/09/20, 8:20 am - Akash Boyz: eda ithonn enik just list aayt prnj tharo
# 19/09/20, 8:27 am - Sam😎: <Media omitted>
# 19/09/20, 8:27 am - Sam😎: Ryzen 3 latest gen
# Asus motherboard
# 8gb DDR4 ram
# 1tb 7200rpm hdd
# 19/09/20, 8:28 am - Akash Boyz: <Media omitted>
# 19/09/20, 8:30 am - Sam😎: <Media omitted>
# 19/09/20, 8:35 am - Akash Boyz: monitor avde inden prnj
# 19/09/20, 8:36 am - Akash Boyz: eda ith just billing pinne aah cctv de koode nokan aaan..... anganethe oru use n maathrm ullath mathi
# 19/09/20, 8:51 am - Sam😎: <Media omitted>
# 19/09/20, 8:54 am - Akash Boyz: ok
# 22/09/20, 10:12 am - Sam😎: 😍🥳
# 22/09/20, 10:52 am - Akash Boyz: ✌🏻
# 25/09/20, 8:08 am - Akash Boyz: daaa
# 25/09/20, 8:09 am - Akash Boyz: ca btech aana integrated msc aana nallath❓
# 25/09/20, 8:20 am - Sam😎: <Media omitted>
# 25/09/20, 8:23 am - Akash Boyz: che ca alla cs
# 25/09/20, 8:23 am - Akash Boyz: type cheythappa maaripoy
# 25/09/20, 8:24 am - Sam😎: <Media omitted>
# 25/09/20, 8:24 am - Sam😎: <Media omitted>
# 25/09/20, 8:26 am - Akash Boyz: ok
# 15/10/20, 8:24 pm - Sam😎: Daa
# 15/10/20, 8:24 pm - Sam😎: Ninte lenovo s145 alle
# 15/10/20, 8:24 pm - Sam😎: Engane inde... Oru review para
# 15/10/20, 8:33 pm - Akash Boyz: ithalla
# 15/10/20, 8:33 pm - Akash Boyz: v330
# 15/10/20, 8:45 pm - Sam😎: <Media omitted>
# 15/10/20, 8:48 pm - Akash Boyz: i3 aan 7th gen
# 15/10/20, 8:48 pm - Akash Boyz: 4gb 512gb
# 19/07/24, 2:08 pm - Akash Boyz: <Media omitted>
# 19/07/24, 2:13 pm - Sam😎: 😂
# 26/07/24, 8:24 pm - Akash Boyz: eda python interns nte nokanind
# 26/07/24, 8:24 pm - Akash Boyz: aarleum indel paray
# 26/07/24, 9:45 pm - Sam😎: Ys naale resume ida
# 27/07/24, 2:21 pm - Sam😎: <Media omitted>
# 27/07/24, 5:20 pm - Akash Boyz: eda ith pdf aayt ayakan para
# 27/07/24, 5:22 pm - Sam😎: Okk
# 29/07/24, 6:11 am - Sam😎: <Media omitted>
# 29/07/24, 10:07 am - Akash Boyz: 🫱🏼‍🫲🏼
# 14/09/24, 6:08 am - Sam😎: Are you free to gather at Tinkerspace, Kalamassery on 22nd September 2024 !?
#
# Join us for Override.py - Pygrammers Community Meetup on 22nd September, 9:30 AM at Tinkerspace, Kochi.
#
# Whether you're an industry professional, a student, or someone passionate about Python, this event is for YOU! Expect networking, knowledge sharing and collaborative learning sessions that will pave the way for our new leadership team and future initiatives.
#
# This is where the Next Phase of Pygrammers begins! 🌟
#
# 🔥 What’s in store:
# ➡️ Networking & tech talks
# ➡️ Discussions on the future of Pygrammers
# ➡️ Kickoff of Pygrammers Learning Initiatives
#
# 🎫 Register now: https://makemypass.com/override.py
#
# Let’s build the future of Python together! 🖥️✨
# 14/09/24, 7:51 am - Akash Boyz: 22 n njn ivde illa
# 14/09/24, 7:58 am - Sam😎: Okk
# 14/09/24, 7:58 am - Sam😎: Trip?
# 14/09/24, 8:18 am - Akash Boyz: eyy alpy l onam
# 14/09/24, 8:21 am - Sam😎: Oh angane
# 27/09/24, 3:44 pm - Sam😎: Da
# 27/09/24, 3:44 pm - Sam😎: Avada opening indel parayane😅
# 27/09/24, 4:03 pm - Akash Boyz: ippa thalkalatheyk onnum vannillada
# 27/09/24, 4:03 pm - Akash Boyz: nee etha nokane
# 27/09/24, 4:03 pm - Sam😎: <Media omitted>
# 27/09/24, 4:03 pm - Sam😎: <Media omitted>
# 27/09/24, 4:05 pm - Akash Boyz: okaay
# 27/09/24, 4:05 pm - Akash Boyz: <Media omitted>
# 27/09/24, 4:48 pm - Sam😎: Okk
# 01/10/24, 11:30 am - Sam😎: <Media omitted>
# 01/10/24, 11:31 am - Akash Boyz: njn emman bibi amith
# ithrem per enthayalum ind
# 01/10/24, 11:31 am - Sam😎: Enna njanum
# 01/10/24, 11:31 am - Akash Boyz: okay set
# 01/10/24, 11:31 am - Sam😎: 9th thanne alle date
# 01/10/24, 11:32 am - Akash Boyz: yup
# 01/10/24, 11:32 am - Akash Boyz: Wednesday
# 01/10/24, 11:15 pm - Akash Boyz: eda chechi k gift vaangan amazon card vaanga....5 k or 3 k wht do u think
#
# 5k aanel.per person 720 aavum
# 3k aanel 430
# 02/10/24, 5:00 am - Sam😎: <Media omitted>
# 02/10/24, 5:01 am - Sam😎: <Media omitted>
# 02/10/24, 10:16 am - Akash Boyz: njn ath ellarodum choikanind
# 02/10/24, 10:17 am - Akash Boyz: amazon aan btr
# 02/10/24, 10:26 am - Sam😎: Enna edutho
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipykernel_3472/2192675144.py:1: SyntaxWarning: invalid escape sequence '\w'
#   re.split('([\w\W]+?):',messages[3])
# [' adipoli alle\n']

# %%
users,messages
# Out:
# (['Whatsapp',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Akash Boyz',
#   'Sam😎',
#   'Sam😎',
#   'Akash Boyz',
#   'Sam😎',
#   ...],
#  ['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#   ' ❤\n',
#   ' Njanum kandaarnne..... 🥳\n',
#   ' adipoli alle\n',
#   ' Ya\n',
#   ' But s4 kittanilla...\n',
#   ' Nxt episode kaanan premium account venam... 😑\n',
#   ' oh dark\n',
#   ' s4 vannit illala\n',
#   ' vann kazhinna terrarium tv il indavum\n',
#   ' ath use cheyth kaana\n',
#   ' bt ath ella phnlim  open aavilla\n',
#   ' matte play protect chelpo dark aakum\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' aah ep 4\n',
#   ' athaa udheshiche\n',
#   ' maaripoy\n',
#   ' ath vannit illala\n',
#   ' <Media omitted>\n',
#   ' njn thodangiyoll\n',
#   ' ith njn nokit kandillala\n',
#   ' <Media omitted>\n',
#   ' aaahm\n',
#   ' aah allel telgram enkilum indavum\n',
#   ' Njaan nokkitte kittilla.... 😬\n',
#   ' aah nokkatr\n',
#   ' <Media omitted>\n',
#   ' aah varumayirikum\n',
#   ' coming soon alle\n',
#   ' 😂\n',
#   ' 😁\n',
#   ' Da\n',
#   ' Ennai nokki paayum thotta eppalaa erangiye.... Nallenaa....\n',
#   ' korch\n',
#   ' ayii\n',
#   ' nallathaanna prnje\n',
#   ' ntha mone ppdi\n',
#   ' LiFi😌\n',
#   ' ennit\n',
#   ' 3G😑\n',
#   ' vry gd🤝🏻\n',
#   ' Ninakke vella ideaum indaa....\n',
#   ' ith vare illa\n',
#   ' Daa work aayi.... 🤩💪🏻\n',
#   ' ehhh🤩🤩🤩🤩\n',
#   ' pwoli\n',
#   ' <Media omitted>\n',
#   ' actually nee ntha cheythe\n',
#   ' <Media omitted>\n',
#   ' set....\n',
#   ' naala video idan marakkalle\n',
#   ' Njaanum kandu...... 🔥\n',
#   ' adipoli alle\n',
#   ' Ya.... 🤩\n',
#   ' 😍\n',
#   ' Daa....\n',
#   ' parayada\n',
#   ' Oru sceen ende....\n',
#   ' nthay\n',
#   ' Oru junior koche inne vanne propose cheythe.. Ozhivaakkan Nthelum vazhi para...\n',
#   ' aah nalla aaloda\n',
#   ' 😂😂😂😂\n',
#   ' enik set aakan alle sire ariyu....ozhivakkan ariyillallo\n',
#   ' 🙊\n',
#   ' Totally confused......\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' aahaaa\n',
#   ' ennit\n',
#   ' Korache shokam alle...\n😬\n',
#   ' cherthayit\n',
#   ' eda ivalde name ntha\n',
#   ' evdeyo kanditulla pole\n',
#   ' Aiswarya\n',
#   ' aaah....appa arinjooda\n',
#   ' bt evdeyo kanda pole\n',
#   ' Veede aroor side aa....\n',
#   ' aah\n',
#   ' ennit nthay\n',
#   ' Onnum aayilla...\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' 🤞🏻\n',
#   ' 🤝🏻\n',
#   ' 🤩🤩🤩\n',
#   ' dhe matte koch\n',
#   ' <Media omitted>\n',
#   ' nthaay\n',
#   ' <Media omitted>\n',
#   ' nallatha\n',
#   ' 😬\n',
#   ' dhe pinnem aah koch\n',
#   ' <Media omitted>\n',
#   ' 🤝🏻\n',
#   ' Nthe parupaady aa\n',
#   ' redhat\n',
#   ' Kettattende..... 😂\n',
#   ' 😁😁\n',
#   ' 🙄🙄🙄\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' 12 lakh\n',
#   ' 😆🤞🏻\n',
#   ' 🤝🏻🤝🏻🤝🏻\n',
#   ' Daa\n',
#   ' Ninakke cpp padikkan indaa\n',
#   ' illa\n',
#   ' c aan\n',
#   ' Flow chart varache tharo....\n',
#   ' nthinte\n',
#   ' 🙄\n',
#   ' daa\n',
#   ' nee flow chart nte karym prnjille\n',
#   ' ath enganan onn prnje\n',
#   ' enik clr code\n',
#   ' vech kandpidikanath ormilla\n',
#   ' marannoy\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' Ithule vellom ariyoda...... 😬\n',
#   ' ithoke nthaan🙄\n',
#   ' go corona\n',
#   ' <Media omitted>\n',
#   ' Motham color aanallo.... 🤭\n',
#   ' 😁😁😁😁\n',
#   ' daa Ubuntu grub menu access cheyyana engana\n',
#   ' kitti da\n',
#   ' On aakkumba shift njekkypidi..\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' ee root@user-Lenovo-V330-14KB\n',
#   ' ath ethaan\n',
#   ' <Media omitted>\n',
#   ' kitti kitiii\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' ed ith partiton cheyyanath engnan ariyo\n',
#   ' ithil windows illa\n',
#   ' <Media omitted>\n',
#   ' eda nee enik windows install cheyth tharo\n',
#   ' njn naale ang varatte\n',
#   ' Athaayirikkum nallathe... 😂\n',
#   ' eppa vannam\n',
#   ' Naala vilikke parayaa...\n',
#   ' ahm\n',
#   ' windows edkan patto\n',
#   ' njn seprate download cheyyano\n',
#   ' njan dwnlaod cheytholam....\n',
#   ' oki\n',
#   ' naale njn vlika\n',
#   ' ok....\n',
#   ' ✌🏻\n',
#   ' daaa\n',
#   ' ang varatte\n',
#   ' <Media omitted>\n',
#   ' ahm\n',
#   ' ✌🏻\n',
#   ' Lap model ethada..\n',
#   ' lenovo v330\n',
#   ' daa\n',
#   ' naale varatte\n',
#   ' <Media omitted>\n',
#   ' enik ippa Windows mathi\n',
#   ' pinna kali kittiyal kollayrn\n',
#   ' ubuntu aan kedakanath\n',
#   ' ubuntu study use n vendi maathrayt use cheyyanan\n',
#   ' windows set aakit venm phn l ullath okke onnn backup cheyyan\n',
#   ' <Media omitted>\n',
#   ' mattanna vara\n',
#   ' 🤝\n',
#   ' daa naale varatte\n',
#   ' Ok da...\n',
#   ' eppa vannam\n',
#   ' ❓\n',
#   ' Nee vilikke\n',
#   ' ahm\n',
#   ' da oru 2 mani kazghinj erangatte\n',
#   ' <Media omitted>\n',
#   ' pani yaa\n',
#   ' ravile eppa\n',
#   ' da eppa vannam\n',
#   ' daa\n',
#   ' nee windows l disk c maathrm vecholla❓\n',
#   ' <Media omitted>\n',
#   ' c mathroll\n',
#   ' <Media omitted>\n',
#   ' ahm n\n',
#   ' nokate\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' daa pinney... aa mouse gesture onnum wrk aavanilla\n',
#   ' <Media omitted>\n',
#   ' ahm\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' nokate\n',
#   ' ithaana\n',
#   ' <Media omitted>\n',
#   ' Atheda..\n',
#   ' ahm\n',
#   ' volume label aana d nn kodukane\n',
#   ' <Media omitted>\n',
#   ' ok\n',
#   ' ithipo ethra size aan\n',
#   ' <Media omitted>\n',
#   ' ipo  lapil storage engana partition cheythekane\n',
#   ' eda ennitum aah disk this pc l kaananilla\n',
#   ' <Media omitted>\n',
#   ' aahda\n',
#   ' set aay\n',
#   ' pinne eda ee brightness control cheyyan pattanilla\n',
#   ' Nee aa fn keg njekky pidichonde function key njekke\n',
#   ' nerthe pattanidarnilla\n',
#   ' ippa sheri aay\n',
#   ' ✌🏻\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' eth version❓\n',
#   ' <Media omitted>\n',
#   ' oki\n',
#   ' <Media omitted>\n',
#   ' ithentha ingane\n',
#   ' <Media omitted>\n',
#   ' aanalle\n',
#   ' 😂\n',
#   ' maatan valla vazhi inda\n',
#   ' <Media omitted>\n',
#   ' desktop il maathrm ullu\n',
#   ' <Media omitted>\n',
#   ' ahm noka\n',
#   ' feature aanen thonnanill\n',
#   ' <Media omitted>\n',
#   ' ahm\n',
#   ' ✌🏻\n',
#   ' daa nee ann flutter course nte kaarym prnjarnille\n',
#   ' aah site onn sent cheyyo\n',
#   ' https://www.appbrewery.co/p/intro-to-flutter\n',
#   ' ✌🏻\n',
#   ' daa\n',
#   ' enik lap l kali koode kettanam... enagana cheyyanden onn prnj tharo\n',
#   ' <Media omitted>\n',
#   ' athengana cheyyaana\n',
#   ' Virtual box download cheyy\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' https://youtu.be/Va37c30zA-M\n',
#   ' Daa ithinte 4 part aatte inde...\n',
#   ' Pattavunnathe kande athyavashyam idea okke kittiyaa nirthikko...\n',
#   ' https://youtu.be/oXsWE9XRVC0\n',
#   ' Ithe git inte series aane athe full kando..\nKorache illu\n',
#   ' ithrem otta day konde theerkkanam...\n',
#   ' Bhakky pinna parayaa\n',
#   ' naale strt cheyya....\n',
#   ' 🤘🏻\n',
#   ' ✌🏻\n',
#   ' daaa\n',
#   ' virtual box il  kali setup cheyyaney.... ethra space kodukanath aayekum nallath\n',
#   ' 10 kodutho\n',
#   ' 10 nth\n',
#   ' eda ram nte kaarym aan\n',
#   ' Ninta 4 alle\n',
#   ' 1 itto\n',
#   ' Lag vellom vanna pinneede 2 aakkiyaa mathy\n',
#   ' aah 1 aan ittekane\n',
#   ' <Media omitted>\n',
#   ' ❓\n',
#   ' Ys\n',
#   ' ❓\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' donain bane blank aanalla\n',
#   ' ath angane thanne mathita\n',
#   ' Ys\n',
#   ' <Media omitted>\n',
#   ' daa\n',
#   ' <Media omitted>\n',
#   ' Ninte name\n',
#   ' 1st\n',
#   ' ahm\n',
#   ' daa\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' grup onnum load aakan pattanindarnilla\n',
#   ' You deleted this message\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' 2 pravashym cheyth\n',
#   ' athonnum kandillala\n',
#   ' daaaa\n',
#   ' nta aniyan ubuntu maati windows aakanm\n',
#   ' ntha cheyyande\n',
#   ' onn simple aayt prnje\n',
#   ' daa\n',
#   ' njn lap open aakumba ippa os select cheyyan vannilla\n',
#   ' direct windows lek povaan\n',
#   ' Biosil kere\n',
#   ' bios f2 aayrnille\n',
#   ' keri\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' itt\n',
#   ' set aat\n',
#   ' y\n',
#   ' daa\n',
#   ' nta manjaro kaanan illa\n',
#   ' 😅\n',
#   ' Nee Nthaa cheithe...\n',
#   ' <Media omitted>\n',
#   ' onn triple boot nokitha...\n',
#   ' 😁\n',
#   ' Nthe itte...\n',
#   ' Kali aana\n',
#   ' bt aah partition avde thanne ind\n',
#   ' aah... vb l pattanindarnilla\n',
#   ' <Media omitted>\n',
#   ' ahm\n',
#   ' <Media omitted>\n',
#   ' https://pop.system76.com/\n',
#   ' njn nokida... bt enik full load aavanilla\n',
#   ' <Media omitted>\n',
#   ' aahm\n',
#   ' alla... appo aah kedakan partition ooo\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' ya...😅\n',
#   ' ini ippa naale cheyyol..... angat inn ponilla\n',
#   ' Ok..\n',
#   ' naale download cheyth set aakit vlika\n',
#   ' avde chennal whtsapp il vlikane pattol tta\n',
#   ' Sceen illa...\n',
#   ' ahm oki\n',
#   ' naale set aakit vlika\n',
#   ' daa\n',
#   ' orangaarn\n',
#   ' nee ntha vliche\n',
#   ' <Media omitted>\n',
#   ' shokam onnum thonnilla\n',
#   ' use cheyyan adipoli aan\n',
#   ' njn athikam use cheythitilla....\n',
#   ' korche use cheythollenkilum nallathaytaan thonnith\n',
#   ' ✌🏻\n',
#   ' daa\n',
#   ' njn ippazhan pop download cheythe\n',
#   ' bootable aakit ind\n',
#   ' ntha cheyyande\n',
#   ' <Media omitted>\n',
#   ' ippa cheyyan aan\n',
#   ' daa aah manjaro nta partition format cheythit avde install cheytha pore\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' bt manjaro kayyil illa\n',
#   ' ini ippa onnude ath dwnld cheyyanam\n',
#   ' <Media omitted>\n',
#   ' ath kaananillalo\n',
#   ' ath poyallo\n',
#   ' 😂\n',
#   ' njn ath alle prnje kali nokippa engano ath poyi.  .\n',
#   ' enik thonnan njn manjaro nte sthalath kondpoya kaali idaan nokith....\n',
#   ' 😁\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' nee manjaro de link koode ayach ittek....may be ishtayillel maata\n',
#   ' 😂\n',
#   ' vb l nokit set aayilla.... njn ippa kali set aakit ind\n',
#   ' onnum nadakanilla\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' namde cmd l vann nikulle oru blank aream oru underscore.. athrem vannoll\n',
#   ' https://parrotlinux.org/\n',
#   ' Ithe kalinelum nallene...\n',
#   ' aahm\n',
#   ' ippa njn install cheyth\n',
#   ' Set aayaa...\n',
#   ' ith njn use cheythitind\n',
#   ' frnd nte lap il\n',
#   ' aah ath set aay\n',
#   ' Windows poyillalla...\n',
#   ' ey illa😁\n',
#   ' Engi ithe thanne itta mathy... Kalinelum stable aane...\n',
#   ' njn ippa aah course nokana konda kali itte.....ath kazhinj maatum\n',
#   ' <Media omitted>\n',
#   ' 2um same aada....\n',
#   ' Ui mathram vethyasam illu..\n',
#   ' ini ippa nthayalum install cheyth.... ini pinna maata.....\n',
#   ' Kaliyaa....\n',
#   ' ah\n',
#   ' Appo pop alle kettiye...\n',
#   ' pop alla\n',
#   ' kali set aay nna prnje\n',
#   ' 😂\n',
#   ' pop cheyyan ponoll\n',
#   ' Athe para...\n',
#   ' 😂\n',
#   ' 3 enno.... 🥺\n',
#   ' aah.... nokatte....\n',
#   ' <Media omitted>\n',
#   ' njn prnjille parrot oruthante lap il use cheyythen avn ithilum kornja lap il ingana use cheyythe scn onnum indarnilla\n',
#   ' onn nokate\n',
#   ' ✌🏻\n',
#   ' Sceen allelum indakilla...\n',
#   ' Linux ninta lapil okke Nthaayalum smooth aayirikkum\n',
#   ' Space aane shokam...\n',
#   ' ippa pop ntha cheyyanden onn simple aayt prnje..... manjaro nde partition njn thottatilla\n',
#   ' aah athum sheri aan\n',
#   ' Kali avada alle ittathe...\n',
#   ' Manjaro partition oru ext4 filesystem delete aakky avada pop kette...\n',
#   ' Manjaro partition formal aayillel nee kalile grub install cheythaal athe edukka..\n',
#   ' alla... athyaa. ariyand avde idaan poy.... bt installation cmplt cheythillarn.... innn vere partition set aakit install cheyth\n',
#   ' athengana cheyyum\n',
#   ' ithinum mathram space engane oppikkane... 😂 Vere padam onnum kertti ittattille..\n',
#   ' njn angne cinema onnum lapilek kettitilla.. ellam phnl kand kalayum\n',
#   ' Installation choikkana avada manual partition enna option ende... Athe kodukkumba partition table varum..\n',
#   ' nta phnle photo video k onninum backup indarnilla.... ath maathre lapil ullu\n',
#   ' njn ippa Windows kerit aah 30 gb partition ang free aakiya pore\n',
#   ' ennit ath select cheytha pore\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' appazthekum njn ee 500gb kootullo....\n',
#   ' Anganaanel sceen illa....\n',
#   ' <Media omitted>\n',
#   ' ippa just onn ariyaan vendi maathraan\n',
#   ' ✌🏻\n',
#   ' just onn familiarized aavan\n',
#   ' eda pop install cheyth... bt ippa kali kaananilla\n',
#   ' ithenthith\n',
#   ' 😂\n',
#   ' Daa grub install cheyy ellam varum...\n',
#   ' Kalide boot partition pop kondoyi athaa...\n',
#   ' engana\n',
#   ' eh... njn vere space il aanalla pop install cheythe\n',
#   ' Oru cheriya partition koody keri varum efi athaane bootloader\n',
#   ' Athe chelappo replace aayi poi kaanum\n',
#   ' Biosil kaanikkanillengy grub install aakke\n',
#   ' ath njn vere indakothaarnalla\n',
#   ' https://m.youtube.com/watch?v=TE6YjpZLHNE\n',
#   ' pop idan vendit manjaro nte 30 gh free aaki.... athin oru 2 gh /boot n vendi koduth\n',
#   ' Oru 300 mb okke ella partition\n',
#   ' Appo kalide boot partition avada thane indaarnna...\n',
#   ' ippa matte bios boot option il kaananth Windows pop pinne efi aan\n',
#   ' athavde ind\n',
#   ' aah partition maatam onnum illa\n',
#   ' Nee ithe cheyy\n',
#   ' aah ith naale noka... ivde netwrk nallapole ulla kond onnum cheyyan pattulla..... naale ang potte\n',
#   ' 😂✌🏻\n',
#   ' 😁\n',
#   ' aah oro error varatte... inganekka alle padikane\n',
#   ' daa\n',
#   ' ippa vere scn\n',
#   ' strt menu wrk aavanilla\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' Bug aada...\n',
#   ' njn 2-3 vattam restart cheyth\n',
#   ' Athe thaniye ready aakum....\n',
#   ' Enikke edakke kittarende...\n',
#   ' ahnalle...\n',
#   ' appa okke\n',
#   ' <Media omitted>\n',
#   ' daa\n',
#   ' nee manjaro nte eth nokaana prnje❓\n',
#   ' xfce.... kde... gnome❓❓❓❓❓\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' ooki🤘🏻\n',
#   ' pop oru ith illa....\n',
#   ' Pop gnome aane ...\n',
#   ' Latest specs eppalum manjarole aane kittane..\n',
#   ' oru sugam thonnanilla\n',
#   ' 🤘🏻\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' njnum nokkate\n',
#   ' daaa\n',
#   ' nta aniyan oruthaney.... tv pc aakana kaaryam parayanindayrn avnte....\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' ithaan tv\n',
#   ' <Media omitted>\n',
#   ' aanalle\n',
#   ' eda pinney... njn manjaro kde install cheythayrn.... bt lap strt aavumba thanne  automatically yakuake strt aavan\n',
#   ' Nthe...\n',
#   ' <Media omitted>\n',
#   ' Kde le grub ende\n',
#   ' matte terminal polathe saathanm ille\n',
#   ' Ithe aanaa\n',
#   ' Start njekky autostart\n',
#   ' Athil yakuake disable aakke\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' set🤝🏻\n',
#   ' <Media omitted>\n',
#   ' njn innale install cheytholl...\n',
#   ' onn nokate\n',
#   ' njn use cheythilla sherik...\n',
#   ' Koree themes okke inde\n',
#   ' Mac pole okke aakka\n',
#   ' njn nokane ullu....\n',
#   ' inn ippo ellam set aakan vech edthatha.... appazha ee sathanm vannath..... pinne athinte porke aayrn\n',
#   ' 😅\n',
#   ' nokate\n',
#   ' daa\n',
#   ' ningade broadband ee kerala vission thanne alle\n',
#   ' Ahda\n',
#   ' Nthaai\n',
#   ' edkaan aan\n',
#   ' eda ivde aduth ithinte office evdaan\n',
#   ' Ninte veetil aana...\n',
#   ' Kishor Kerala Vision.vcf (file attached)\n',
#   ' aah ingere vlich\n',
#   ' dark aan\n',
#   ' Avada aanel ingere vilichaa mathy\n',
#   ' Nthaa sceen\n',
#   ' Ninte area vere illa...\n',
#   ' avrde modem kittan dark aavumn prnj\n',
#   ' time edkumn\n',
#   ' Athe nee oppikkanne para\n',
#   ' vere medikan aanel ath thanne venmn\n',
#   ' Modem namukke set aakka\n',
#   ' net link nte\n',
#   ' Netlink aple\n',
#   ' Sceen illa...\n',
#   ' njn nokit kittanilla\n',
#   ' online illa\n',
#   ' <Media omitted>\n',
#   ' Ready aakky tharaada\n',
#   ' adutha azhacha enn paryumbo inn ippo sunday alle\n',
#   ' ✌🏻✌🏻✌🏻\n',
#   ' Ys\n',
#   ' Nee wait\n',
#   ' Ippo out of stock aa oppikka\n',
#   ' waitaam\n',
#   ' Pullinode huawei epon modem pattonne choikke...\n',
#   ' pulli voice venmn prnj\n',
#   ' athil\n',
#   ' Endedaa\n',
#   ' enik ee modem aayt athrayk parichaym illa\n',
#   ' <Media omitted>\n',
#   ' aahnalle\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' aah njn inn noka\n',
#   ' vlich\n',
#   ' ✌🏻\n',
#   ' ithin rate ethravum\n',
#   ' Ekadesham 2500\n',
#   ' ah ok\n',
#   ' <Media omitted>\n',
#   ' njn choichit paraya\n',
#   ' athin onnum prnjilla\n',
#   ' ivde aduth already oru veetil ind...\n',
#   ' <Media omitted>\n',
#   ' aahdaa\n',
#   ' njn vlichit paraya\n',
#   ' ithaanel vekm set aakan patto❓\n',
#   ' Indiamart ario...\n',
#   ' no\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' aahda nokatte\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' eda ithaan kaanikane\n',
#   ' netlink evadelum indaakum\n',
#   ' adil full ithaann\n',
#   ' <Media omitted>\n',
#   ' pinne dhith\n',
#   ' Athe gpon aane ninakke pattulla...\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' ithalle saathanm\n',
#   ' You deleted this message\n',
#   ' Ithe thannene... But vilikkumbo epon support endaanne choichere...\n',
#   ' Rate ethrene\n',
#   ' rate kaatitillq\n',
#   ' ariyill dualmode enn ind\n',
#   ' <Media omitted>\n',
#   ' aah\n',
#   ' ith chennai ntho aan koduthekane\n',
#   ' Avar avadanne ayakkum...\n',
#   ' Aa oru time edukkollu\n',
#   ' Call cheythe nokkiyaa\n',
#   ' payment enganavum\n',
#   ' illa\n',
#   ' <Media omitted>\n',
#   ' achan orangaan paysa engane set aakumn choichit vlikan vech\n',
#   ' <Media omitted>\n',
#   ' aahm✌🏻\n',
#   ' vlikatte\n',
#   ' <Media omitted>\n',
#   ' aahda ath choika\n',
#   ' ivare vlich\n',
#   ' ivde aduth vytla le oru num thann\n',
#   ' avde contact cheya\n',
#   ' ippo vlichit edukanilla\n',
#   ' sunday oke alle\n',
#   ' naale raavile vlich noka\n',
#   ' Appo pettanne kittollo sadanam.... 😁\n',
#   ' aah kittiya mathiyarn\n',
#   ' daa\n',
#   ' manjaro install cheyyumba ethoke partition vennm\n',
#   ' boot root swap ❓❓❓\n',
#   ' Athrem mathy\n',
#   ' root main aayt ullath\n',
#   ' total 30 fb yil aan ith cheyyane\n',
#   ' oronnum ethra kodukkanm\n',
#   ' <Media omitted>\n',
#   ' aake ullath ippo 30 gb aan\n',
#   ' athil ninnond vende ithoke kodukan\n',
#   ' Aahda\n',
#   ' 🤘🏻\n',
#   ' Ban...? Appo last month ban aakkiyatho....\n',
#   ' last month aakillla... aakan plan inden aayrn\n',
#   ' <Media omitted>\n',
#   ' daaa\n',
#   ' ninak ith cheyyan patto❓\n',
#   ' <Media omitted>\n',
#   ' ith koode\n',
#   ' <Media omitted>\n',
#   ' clsooooo\n',
#   ' eth clssss\n',
#   ' online alle❓\n',
#   ' <Media omitted>\n',
#   ' adipoli\n',
#   ' nee onn nok\n',
#   ' patto nn\n',
#   ' <Media omitted>\n',
#   ' nta chettan nikkana oru kada aan\n',
#   ' allel vere nokan parayam\n',
#   ' Sthalam evadaada\n',
#   ' menaka avde evdo aano\n',
#   ' eda ith cheyyan rate ethrayavum❓\n',
#   ' njney ninte num kodukatte\n',
#   ' daaa\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' eda ithonn enik just list aayt prnj tharo\n',
#   ' <Media omitted>\n',
#   ' Ryzen 3 latest gen\nAsus motherboard\n8gb DDR4 ram\n1tb 7200rpm hdd\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' monitor avde inden prnj\n',
#   ' eda ith just billing pinne aah cctv de koode nokan aaan..... anganethe oru use n maathrm ullath mathi\n',
#   ' <Media omitted>\n',
#   ' ok\n',
#   ' 😍🥳\n',
#   ' ✌🏻\n',
#   ' daaa\n',
#   ' ca btech aana integrated msc aana nallath❓\n',
#   ' <Media omitted>\n',
#   ' che ca alla cs\n',
#   ' type cheythappa maaripoy\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' ok\n',
#   ' Daa\n',
#   ' Ninte lenovo s145 alle\n',
#   ' Engane inde... Oru review para\n',
#   ' ithalla\n',
#   ' v330\n',
#   ' <Media omitted>\n',
#   ' i3 aan 7th gen\n',
#   ' 4gb 512gb\n',
#   ' ee specs intethaya limit indenne ullu... use cheythit enik athyavashym nallathayt aan thonniyekane\n',
#   ' ✌🏻\n',
#   ' ee wireshark netwrk monitoring tool alle❓\n',
#   ' Aahda\n',
#   ' Njngakke athokke inde lab\n',
#   ' Wireshark oru paper aane..\n',
#   ' adipoli\n',
#   ' ningalk athoke indalle\n',
#   ' njnglk inganatha oru item polum illa padikaan\n',
#   ' padikanath full etho jambavante kaalath ulla items\n',
#   ' <Media omitted>\n',
#   ' njngalk cryptography okke ind.... bt athoke pandathe syllabus aan\n',
#   ' 😹\n',
#   ' <Media omitted>\n',
#   ' njnhalk angane development polum illa\n',
#   ' pinne njngal ippo padikana processor polum pandathethan\n',
#   ' ethra advanced vannitindelum athonn kaanan polum pattulla\n',
#   ' Ktu.... 😂\n',
#   ' <Media omitted>\n',
#   ' future IIT🤭\n',
#   ' ponn mone atha prnje ann ktu edkallen\n',
#   ' <Media omitted>\n',
#   ' aah njngalk anganatheth eee final yr aan.. athum njngade teachers thanne dark aan\n',
#   ' enik ippa ith vazhi google cloud nte oru prgrm kitti.... anganathe korch nallath ind\n',
#   ' Ningakke placement okke ippalalle...\n',
#   ' Vellathum aayaa\n',
#   ' ithrem supply ulla kond enik kittulla\n',
#   ' cgpa 6 venm\n',
#   ' <Media omitted>\n',
#   ' no supply alllel atmost 1 supply ullavarke ullu\n',
#   ' angane njn nokkanilla\n',
#   ' <Media omitted>\n',
#   ' yah dhipo edthol account\n',
#   ' 😅✌🏻\n',
#   ' github koode set aakanm\n',
#   ' enik indo illayon aan doubt\n',
#   ' eppazho start cheytha pole oru orma ind\n',
#   ' <Media omitted>\n',
#   ' 😂\n',
#   ' daa ann nee status ittayrnille JL stadium....\n',
#   ' ath inda kayyil\n',
#   ' <Media omitted>\n',
#   ' nee edthathaana ith\n',
#   ' Aahda\n',
#   ' Njaan stadium alla njngada coleg ground aa uddeshiche... 😅\n',
#   ' ath pic kandappazhe thonni\n',
#   ' Da\n',
#   ' parayda\n',
#   ' daaa oru app development basic nthokeya aavashym ulla technologies\n',
#   ' Android aano\n',
#   ' yah\n',
#   ' Java or kotlin aadyam അറിയണം\n',
#   ' kotlin aan nokane\n',
#   ' Pinne ethe level app aanenne vechaa athinanusariche database okke ariyaam\n',
#   ' അറിയണം\n',
#   ' ok\n',
#   ' Jdbc and also backend connect cheyyan okke അറിയണം\n',
#   ' ith enganan\n',
#   ' njngalk project n aan\n',
#   ' Database connectivity....\n',
#   ' naale oru basic idea kodukanm\n',
#   ' Njan korache kazhinje varaa clazilaa...\n',
#   ' appo technology stack nthaan parayanm\n',
#   ' oki🤝🏻\n',
#   ' njnum clsil aan😁\n',
#   ' 😆\n',
#   ' koode fuding m ind\n',
#   ' Ninte project Nthaa uddeshikkane....\n',
#   ' eda disaster management aan aim\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' Athine database connectivity okke vende....\n',
#   ' Nalla backendum venam.\n',
#   ' <Media omitted>\n',
#   ' venm\n',
#   ' venm\n',
#   ' ithe nee enganaa present cheyyan pone.  .. 😂\n',
#   ' thampuranariya\n',
#   ' ippa thalkalam technology stack enganelum oppich just oru introduction set aakiya maathi\n',
#   ' baaki okke pinnen\n',
#   ' implementation nxt sem aan\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' aah ath dark aavum\n',
#   ' kotlin n pakaram flutter use cheyyan alle\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' aahnalle... appa scn illa\n',
#   ' baaki ulla kaaryangal okke enganan ennan ariyandath\n',
#   ' ithil nthayalum oru map aavashym varulle\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' athalladw implement cheyyumbo nammal ippo gmao use cheyyana pole vannam\n',
#   ' idea kittyvanel njn paraya\n',
#   ' <Media omitted>\n',
#   ' matte virtual conference okke ille.... cinema  l kaanikane pole\n',
#   ' ithe sherikkum Nthaa parupadi...\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' online\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' daaa\n',
#   ' oru 40000 budget l nalla oru lap prnje\n',
#   ' <Media omitted>\n',
#   ' eee rate specs ethra vare kittum\n',
#   ' Nee ajaynode choikke avan ee aduthe orennam edutharnne.... Njaan use cheythatte nice aane....\n',
#   ' eth ajay🙄\n',
#   ' <Media omitted>\n',
#   ' aah avnoke aayt oru connection um. illa\n',
#   ' Ajay dev.vcf (file attached)\n',
#   ' <Media omitted>\n',
#   ' aahda\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' avlod prnj maataan.... kekande ival\n',
#   ' eda windows nammal kadayil poy ityal ethra aavum\n',
#   ' Athe ariyilla.... Depend cheyyum...\n',
#   ' Kadenne aane medikkanengy avar thanne free aayi itte tharum....\n',
#   ' kadayil windows ullathin 45 aavumn\n',
#   ' matteth 38\n',
#   ' Forrun.vcf (file attached)\n',
#   ' Ivada choiche nokke rate..\n',
#   ' ahda\n',
#   ' eda windows nammal cheyyanathaana kadayil poy cheyyanathaana nallath\n',
#   ' Ninte net ready aaya...\n',
#   ' yaah\n',
#   ' Enna nee thanne cheyy\n',
#   ' enikalla... alapuzha aan...\n',
#   ' Kadele cheythaa bugs indaakum..\n',
#   ' windows kayyil indel ath vech cheytha pore\n',
#   ' Ariyongy namma thanne cheyyanene nallathe...\n',
#   ' Crack alle..\n',
#   ' athe\n',
#   ' Evadanne dwnload cheythathaa\n',
#   ' aah cheyyan ariyanavar ind\n',
#   ' avrde thanne site nn\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' Athe activate okke aakkanam...\n',
#   ' njn nta cusins n athaan itt kodutheche.... activate aakit onnum illa\n',
#   ' 😅\n',
#   ' Vere sceen onnulla korache kazhiyumba activate enne paranje kaanichondirikkum...\n',
#   ' adiyil alle.... activate ur windows n prnj\n',
#   ' Aah\n',
#   ' vere onnum illalolle\n',
#   ' https://getintopc.com/softwares/operating-systems/windows-10-pro-updated-may-2020-free-download-1493923/\n',
#   ' ithe nice aane...\n',
#   ' Close to genuine....\n',
#   ' <Media omitted>\n',
#   ' nokkatte\n',
#   ' njn ith pole korch edth vechekaayrn\n',
#   ' Send...😂\n',
#   ' ithe infoparkile troll page aane\n',
#   ' ithe ellam athil ende... 😂\n',
#   ' njngade grpl oruthan kondvann ittayrn\n',
#   ' daaa\n',
#   ' local disk c maathrm aayt disk vechekana lap  ath shrink cheyth vere disk aaki partition cheythaal scn inda❓\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' dhingane aan\n',
#   ' lap kittippa ee onn indarnoll\n',
#   ' pinne ubuntu live nte kaarym prnjappazha.... kali live use cheyyanath kond nthelum scn indavo\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' shrink indel ath ang cheytha pore....\n',
#   ' nammal shrink cheyyumba size kodukkulle.... ath shrink aay kazhinj aah disk n venda size aana atho matte disk ethra size venmn aana\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' oki✌🏻\n',
#   ' da nee garuda os use cheythitinda\n',
#   ' Eey\n',
#   ' ippo manjaro mathram aane.....\n',
#   ' njn ath onn try cheythalon vech irikaan\n',
#   ' kaanan okke nalla resaan\n',
#   ' ithe custom rom alle phoneil alle\n',
#   ' performance noknm\n',
#   ' eyyy\n',
#   ' arch based os aan\n',
#   ' ?\n',
#   ' ere kore manjaro okke pole thanne\n',
#   ' eda arch linux\n',
#   ' <Media omitted>\n',
#   ' aah ith njn ippa oru video  kandatha\n',
#   ' <Media omitted>\n',
#   ' athikam aayt illan thonnan release aayt\n',
#   ' <Media omitted>\n',
#   ' Endeavouros nokke....\n',
#   ' manjaro okke nalla pole panithayrn.... ith vare use cheythathil ishyayath manjaro thanne aan...\n',
#   ' <Media omitted>\n',
#   ' oron trh cheyan vechan\n',
#   ' similar aan nallapole\n',
#   ' <Media omitted>\n',
#   ' nta manjaro poy... windows onn scan cheythatha..... 😁😁😁\n',
#   ' <Media omitted>\n',
#   ' Aah kolla... 😂\n',
#   ' onnude install cheyyan nokit 95% vare aavanoll\n',
#   ' <Media omitted>\n',
#   ' ooki✌🏻\n',
#   ' 😁\n',
#   ' <Media omitted>\n',
#   ' manjaro nallapole customize cheyyan pattanind\n',
#   ' Ya... 😂\n',
#   ' njn image onnude dwnld cheyyan vechaan\n',
#   ' <Media omitted>\n',
#   ' manjaro l matte konsole aayrnille\n',
#   ' garuda il 2um.ind\n',
#   ' Manjaro kde alle\n',
#   ' Athaa nice\n',
#   ' <Media omitted>\n',
#   ' normal terminal pinne konsole\n',
#   ' <Media omitted>\n',
#   ' njn ippazhaayrn athinte kaarym ariyane.... korch files indayrn athil😑\n',
#   ' yah\n',
#   ' enikum athe pole aan thonniye\n',
#   ' njn konsole use cheyyan padichond irikaryn\n',
#   ' 😂 ✌🏻\n',
#   ' commands okke cheriya vethyasm ille\n',
#   ' <Media omitted>\n',
#   ' appo athonn manasilakilel dark aavum\n',
#   ' aah athoke similar aan\n',
#   ' pinne pcman okke vere alle\n',
#   ' pacman*\n',
#   ' <Media omitted>\n',
#   ' njn nthayalum garuda noka... ennit enganinden paraya....\n',
#   ' aah ath kitti.... angne noki noki\n',
#   ' <Media omitted>\n',
#   ' repositories kolla.,...\n',
#   ' 2um ind\n',
#   ' ennan thonnane\n',
#   ' nokanm\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' ahda.... kore ind athil\n',
#   ' aah nokkate\n',
#   ' Nee install aakkitte para\n',
#   ' oki✌🏻\n',
#   ' Pere kettatte indiakkarude aanenne thonnane...\n',
#   ' grp leader indian aan\n',
#   ' ennalum pala sthalathe aalkar okke chern aan indakiye\n',
#   ' Maharashtra le oru pulli aaan\n',
#   ' <Media omitted>\n',
#   ' rolling release aan\n',
#   ' Nee ithe main aakkanda......\n',
#   ' Stable manjaro aane...\n',
#   ' aah chumma nokaan aan...\n',
#   ' 😁✌🏻\n',
#   ' manjaro thanne pinnem edkum\n',
#   ' enik bayankara ishtay ath\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' njn coding lek athikam keritt illa..... ini ippa project n vendi set aakanm\n',
#   ' windows njn kalayath gaming kond thanne aaan... pinne enda pic videos ellam athil aan ittekane\n',
#   ' Timeshift use cheyyanel nee space korache space kooduthal kodukkendy varum...\n',
#   ' ethra kodukanm\n',
#   ' Ninte use anusariche\n',
#   ' Or nee 60gb main koduthatte.... Oru 30-40gb vere ext4 partition endakkiyaa mathy for timeshift\n',
#   ' njn athikam onnum ith use cheyyarilla.... like video pics angane onnum illa.... coding anganathe files maathrm\n',
#   ' Appo sceen illa... Oru 60 70 total koduthekke android studio okke use cheyyan indel\n',
#   ' Manjaro oru 8gb okke install cheyyumbo edukkollu..\n',
#   ' android studio.... nta lap l.... nadakana kaarym vallom para\n',
#   ' 😬\n',
#   ' Appo sceen illa\n',
#   ' ithintath use cheyyanath athinte konsole aan....\n',
#   ' pinne atom\n',
#   ' ath use cheyyan ponoll\n',
#   ' Njaan ippo android studio onnum illa but vere athyavashyam coding apps okke itte set aakky total oru 25gb okke aayollu\n',
#   ' Vs code aane nallathe...\n',
#   ' ath athikam. ang parichayam illa\n',
#   ' Athaada nice ellam nadakkum athil\n',
#   ' aah ath noka...\n',
#   ' <Media omitted>\n',
#   ' eda njn manjaro partition cheyyumba orennam /boot/efi aan kodukandathennan utube l kaanikane.... kazhinja thavana athe pole thanne aan cheythe\n',
#   ' bt ippa nokumba /boot maathre avde ullu\n',
#   ' net edayk dark aavum\n',
#   ' Installion partitionil aano...\n',
#   ' Athe mathyaakum...\n',
#   ' Boot flag koduthaa mathy\n',
#   ' ivde tv cut aay kedaka.. paysa kodukan aayt pulli ne vlichit edkanum illa\n',
#   ' Election... 😂\n',
#   ' njn ath aan koduthe pinne.....\n',
#   ' bt install aayillayrn\n',
#   ' <Media omitted>\n',
#   ' pulli athinte porake nadakaan\n',
#   ' <Media omitted>\n',
#   ' njn onnum illa\n',
#   ' njngalkum kore aay\n',
#   ' warning onnum illa\n',
#   ' boot flag oke koduthayrn\n',
#   ' <Media omitted>\n',
#   ' fail onnum kaatanillada\n',
#   ' 95% vare load aavum\n',
#   ' baaki anganulla\n',
#   ' ethra nerm wait cheythalum anangulla\n',
#   ' Athe cheleppo files corrupted aayatte aayirikkum...\n',
#   ' <Media omitted>\n',
#   ' ah njn ippa vere dwnld cheyyaan\n',
#   ' yah....ini vanna nokam\n',
#   ' <Media omitted>\n',
#   ' enikum angane thonniyaarn....\n',
#   ' min requirement nta kayyil ullu\n',
#   ' <Media omitted>\n',
#   ' kde dragonized enn prnj orennam ind\n',
#   ' agha nokane\n',
#   ' <Media omitted>\n',
#   ' net edayk speed varum pinne korayum\n. \ndark aan\n',
#   ' athinte koode google meet\n',
#   ' ath edthit njn nth cheyyan aan🥲\n',
#   ' <Media omitted>\n',
#   ' <Media omitted>\n',
#   ' 20\n',
#   ' Combo alle...\n',
#   ...])

# %%
df['users'] = users
df['messages'] = messages
df.drop(columns=['user_messages'], inplace=True)
df.head()
# Out:
#          message_date       users  \
# 0 2019-12-17 13:03:00    Whatsapp
# 1 2019-12-17 12:42:00  Akash Boyz
# 2 2019-12-28 09:21:00        Sam😎
# 3 2019-12-28 09:25:00  Akash Boyz
# 4 2019-12-28 09:28:00        Sam😎
#
#                                             messages
# 0  Messages and calls are end-to-end encrypted. N...
# 1                                                ❤\n
# 2                         Njanum kandaarnne..... 🥳\n
# 3                                     adipoli alle\n
# 4                                               Ya\n

# %%
df['month'] = df.message_date.dt.month_name()
df['day'] = df.message_date.dt.day
df['year'] = df['message_date'].dt.year
df['minute'] = df['message_date'].dt.minute
df['hour'] = df['message_date'].dt.hour

df.head()
# Out:
#          message_date       users  \
# 0 2019-12-17 13:03:00    Whatsapp
# 1 2019-12-17 12:42:00  Akash Boyz
# 2 2019-12-28 09:21:00        Sam😎
# 3 2019-12-28 09:25:00  Akash Boyz
# 4 2019-12-28 09:28:00        Sam😎
#
#                                             messages     month  day  year  \
# 0  Messages and calls are end-to-end encrypted. N...  December   17  2019
# 1                                                ❤\n  December   17  2019
# 2                         Njanum kandaarnne..... 🥳\n  December   28  2019
# 3                                     adipoli alle\n  December   28  2019
# 4                                               Ya\n  December   28  2019
#
#    minute  hour
# 0       3    13
# 1      42    12
# 2      21     9
# 3      25     9
# 4      28     9

# %%
df[df.users == 'Akash Boyz'].messages.shape[0]
# Out:
# 1352

# %%
messages = df[df.users == 'Akash Boyz'].messages
df[df.messages == ' <Media omitted>\n']
# Out:
#             message_date users            messages     month  day  year  \
# 13   2019-12-28 09:46:00  Sam😎   <Media omitted>\n  December   28  2019
# 14   2019-12-28 09:46:00  Sam😎   <Media omitted>\n  December   28  2019
# 19   2019-12-28 09:47:00  Sam😎   <Media omitted>\n  December   28  2019
# 22   2019-12-28 09:48:00  Sam😎   <Media omitted>\n  December   28  2019
# 27   2019-12-28 09:51:00  Sam😎   <Media omitted>\n  December   28  2019
# ...                  ...   ...                 ...       ...  ...   ...
# 2411 2024-11-28 14:48:00  Sam😎   <Media omitted>\n  November   28  2024
# 2415 2024-11-28 14:49:00  Sam😎   <Media omitted>\n  November   28  2024
# 2416 2024-11-28 14:49:00  Sam😎   <Media omitted>\n  November   28  2024
# 2417 2024-11-28 14:49:00  Sam😎   <Media omitted>\n  November   28  2024
# 2418 2024-11-28 14:49:00  Sam😎   <Media omitted>\n  November   28  2024
#
#       minute  hour
# 13        46     9
# 14        46     9
# 19        47     9
# 22        48     9
# 27        51     9
# ...      ...   ...
# 2411      48    14
# 2415      49    14
# 2416      49    14
# 2417      49    14
# 2418      49    14
#
# [662 rows x 8 columns]

# %%
df[df.messages == ' <Media omitted>\n'].messages.iloc[0]
# Out:
# ' <Media omitted>\n'

# %%
from urlextract import URLExtract

extract = URLExtract()
urls = []
for msg in df.messages:
    urls.extend(extract.find_urls(msg))
urls
# Out:
# ['https://www.appbrewery.co/p/intro-to-flutter',
#  'https://youtu.be/Va37c30zA-M',
#  'https://youtu.be/oXsWE9XRVC0',
#  'https://pop.system76.com/',
#  'https://parrotlinux.org/',
#  'https://m.youtube.com/watch?v=TE6YjpZLHNE',
#  'https://getintopc.com/softwares/operating-systems/windows-10-pro-updated-may-2020-free-download-1493923/',
#  'https://docs.google.com/forms/d/e/1FAIpQLSfRUp3kqdDkEFGIsBVaKVudu9AHtPkFvs3cgm7DHEuC5qaruA/viewform',
#  'https://www.google.com/url?sa=t&source=web&rct=j&url=https://www.udemy.com/course/100-days-of-code/&ved=2ahUKEwiuyaWAnO7tAhWCj-YKHZ4hDn4QFjAAegQIBxAC&usg=AOvVaw2Zmffnd0Dv1f6dk2nfVjox&cshid=1609074077549',
#  'https://mega.nz/folder/3dkS2bDK#gYMtinIWJaXsFfVJErcZYA/folder/KN91DQKZ',
#  'https://aur.archlinux.org/visual-studio-code-bin.git',
#  'https://youtube.com/playlist?list=PLbGui_ZYuhigchy8DTw4pX4duTTpvqlh6',
#  'https://forms.gle/mDLWosi7JPtGwo6Q7',
#  'https://wa.me/message/HGP45BEC6M77D1',
#  'https://www.youtube.com/watch?v=uDBA35dVKJs&t=52s',
#  'https://tiny.school/',
#  'https://youtu.be/x6zNu_3hdOU',
#  'https://drive.google.com/file/d/1qC1WD0UHn-bn2J6RPuDl0O9iPlUWatn2/view?usp=sharing',
#  'https://drive.google.com/file/d/1l7mIfwQoX1nVOw3xAbucgUSkq8Sl5VWH/view',
#  'https://www.youtube.com/watch?v=j942wKiXFu8&list=PL4cUxeGkcC9gZD-Tvwfod2gaISzfRiP9d',
#  'https://youtu.be/o0XbHvKxw7Y',
#  'https://www.instagram.com/reel/CUC-_PPB-0h/?utm_medium=share_sheet',
#  'https://www.ktuassist.in/2018/04/download-s7-cse-cryptography-and.html',
#  'https://www.ktustudents.in/2018/11/cs409-cryptography-and-network-security-notes-textbook-syllabus-question-papers-s7-cse.html',
#  'https://geeksgod.com/zoho-is-hiring-software-developer-recruitment-drive/',
#  'https://bit.ly/3FzCZfl',
#  'https://forms.gle/qp9qtu6ouyaB7RLs7',
#  'https://www.mariancollege.org/placements/downloads/Innovature-Labs-Recruitment--(Notification_Dated-28-Feb-2022).pdf',
#  'https://www.ajio.com/netplay-tapered-fit-flat-front-chinos/p/441140299_darkgrey?user=old',
#  'https://www.ajio.com/cantabil-straight-fit-flat-front-chinos/p/465094711_grey?user=old',
#  'https://www.ajio.com/netplay-slim-fit-flat-front-chinos-with-slip-pockets/p/441140126_olive?utm_source=share&utm_medium=share',
#  'Override.py',
#  'https://makemypass.com/override.py',
#  'https://t.me/+3lWR9H4zlBY5OWE1']
